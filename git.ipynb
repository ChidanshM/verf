# %%
# !git pull
# Out:
# remote: Enumerating objects: 2281, done.
# remote: Counting objects: 100% (2281/2281), done.
# remote: Compressing objects: 100% (2233/2233), done.
# remote: Total 2279 (delta 53), reused 2264 (delta 38), pack-reused 0 (from 0)
# Receiving objects: 100% (2279/2279), 410.95 KiB | 6.63 MiB/s, done.
# Resolving deltas: 100% (53/53), completed with 1 local object.
# From https://github.com/ChidanshM/verf
#    6473d56..ff2e973  main       -> origin/main
# Updating 6473d56..ff2e973
# Filtering content: 100% (1426/1426), 25.11 GiB | 37.21 MiB/s, done.
# Fast-forward
#  .gitattributes                                     |    1 +
#  .gitignore                                         |    4 +-
#  column_names.csv                                   |    3 +
#  .../S001/S001_G01_D01_B01_T01-target_features.csv  |    3 +
#  .../S001/S001_G01_D01_B01_T02-target_features.csv  |    3 +
#  .../S001/S001_G01_D01_B01_T03-target_features.csv  |    3 +
# ...

# %%
# !git pull --rebase origin/master

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	new file:   data_cleaning
# 	new file:   database/processed_tensors/S004.pt
# 	new file:   database/processed_tensors/S012.pt
# 	new file:   database/processed_tensors/S016.pt
# 	new file:   database/processed_tensors/S030.pt
# 	new file:   database/processed_tensors/S031.pt
# 	new file:   database/processed_tensors/S033.pt
# 	new file:   database/processed_tensors/S034.pt
# 	modified:   git.ipynb
# 	new file:   output-251211-1539
# 	new file:   output-251211-1552
# 	new file:   output-251211-1616
# 	new file:   output-251211-1623
# 	new file:   processed_tensors/S001.pt
# 	new file:   processed_tensors/S002.pt
# 	new file:   processed_tensors/S003.pt
# 	new file:   processed_tensors/S004.pt
# 	new file:   processed_tensors/S005.pt
# 	new file:   processed_tensors/S006.pt
# 	new file:   processed_tensors/S007.pt
# ...

# %%
# !git add .

# %%
# !git add SimeTamp/t.json && git commit -m "SimeTamp" -m "Updated from GColab"

# %%
# !git reset HEAD

# %%
# !git rm $(git ls-files --deleted)
# Out:
# rm 'database/fep/01-00.tar.xz'
# rm 'database/fep/S041/S041_G02_D01_B01_T01-target_features.csv'
# rm 'database/fep/S041/S041_G02_D01_B01_T02-target_features.csv'
# rm 'database/fep/S041/S041_G02_D01_B01_T03-target_features.csv'
# rm 'database/fep/S041/S041_G02_D01_B02_T01-target_features.csv'
# rm 'database/fep/S041/S041_G02_D01_B02_T02-target_features.csv'
# rm 'database/fep/S041/S041_G02_D01_B02_T03-target_features.csv'
# rm 'database/fep/S041/S041_G02_D01_B03_T01-target_features.csv'
# rm 'database/fep/S041/S041_G02_D01_B03_T02-target_features.csv'
# rm 'database/fep/S041/S041_G02_D01_B03_T03-target_features.csv'
# rm 'database/fep/S041/S041_G02_D02_B01_T01-target_features.csv'
# rm 'database/fep/S041/S041_G02_D02_B01_T02-target_features.csv'
# rm 'database/fep/S041/S041_G02_D02_B01_T03-target_features.csv'
# rm 'database/fep/S041/S041_G02_D02_B02_T01-target_features.csv'
# rm 'database/fep/S041/S041_G02_D02_B02_T02-target_features.csv'
# ...

# %%
# !git ls-files --deleted | xargs git rm

# %%
import subprocess

# Step 1: Get the list of deleted files
deleted_files = subprocess.check_output('git ls-files --deleted', shell=True).decode('utf-8').splitlines()

# Step 2: Remove each file from Git index
if deleted_files:
    for file in deleted_files:
        print(f"Removing {file}")
        subprocess.run(['git', 'rm', file])
else:
    print("No deleted files to remove.")

# %% [markdown]
# chckpnt:26 del
#
# Updated from LS5-POS-2404

# %%
# !git commit -m "chckpnt:29 git" -m "Updated from LS5-POS-2404" -m "to lfs add *.pt"
# Out:
# [main e44a5af] chckpnt:29 git
#  1 file changed, 1 insertion(+)

# %%
# !git commit -m "intitalised gDrive" -m "Updated from gDriveEl" -m ""

# %%
# !git push
# Out:
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 16 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 330 bytes | 330.00 KiB/s, done.
# Total 3 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/ChidanshM/verf/
#    afcc75d..e44a5af  main -> main

# %%
# !git lfs track "*.pt"
# Out:
# Tracking "*.pt"

# %%
# !git lfs prune
# Out:
# 1415 local objects, 885 retained, done.
# Deleting objects: 100% (531/531), done.

# %%
# !git reset --soft HEAD~1

# %%
# !git diff --staged

# %%
# !git stash

# %%
# !git stash list

# %%
# !git merge

# %%
# !git ls-files --others

# %% [markdown]
# # Mount GDrive and Directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/0zSU/cis667/

# %%
# %pwd

# %% [markdown]
# # Trouble shooting

# %%
# !git gc --prune=now --aggressive
# Out:
# Enumerating objects: 2512, done.
# Counting objects: 100% (2512/2512), done.
# Delta compression using up to 16 threads
# Compressing objects: 100% (2489/2489), done.
# Writing objects: 100% (2512/2512), done.
# Total 2512 (delta 87), reused 2363 (delta 0), pack-reused 0

# %%
# !git lfs prune --verbose --dry-run
# Out:
# 884 local objects, 15 retained, done.
# 870 files would be pruned (20 GB)
#  * 5009afd7099389d8762a41b6ec788522991eaf0eb2e62ee950fbea7b6193d24b (19 MB)
#  * 50dc2f046c44f890d1220385220f188470562a62c4008e2b684896457b880000 (19 MB)
#  * cd406ad1686dba2a358af4ca15356e165420651faf715052c2673accb8db8406 (19 MB)
#  * cdabfe0f34aa185f867b893bab228d7f13017149c8137a064afd6db068e386f8 (19 MB)
#  * cd0aa4acd08b42b110cae088f02a6b00c292c11580422bac3c1261718b7de6f1 (19 MB)
#  * cd0dadb0a00fa18f49696b29753bf72478b774e5979318ab7c4dc2ffc601de74 (19 MB)
#  * cd8cd5134ce3f2f9b301b37bb37e66ea4c725c68b11a03975f3cfcf58a10b935 (19 MB)
#  * cdd56611e91e6984f52de7c7f8d7ebb0d19819e2f64c462b482c6d0ac71da70f (19 MB)
#  * cd8a9182047424cbd7bdd1c647cb3c4f61c6c310630b1b5992077a4f2f86e19b (19 MB)
#  * 57e392812c46b5acdd9cf32aef833e52b33e10c958be53978241062e1ca2caf9 (19 MB)
#  * e406653f1e9610bbe1e9ad5c78fc9ea430f7860b89832024000c9e0d198873c9 (19 MB)
# ...

# %%
# !git remote set-url origin https://@github.com/ChidanshM/cis667.git

# %%
# !git remote -v

# %%
# !git remote add origin git@github.com:ChidanshM/verf.git

# %%
# !git branch -M main

# %%
# !git push -u origin main
